# %% [markdown]
# # WEB SCRAPING
#
# There are different ways to scrape data from the net, 1. Using python. 2. Using softwares like Parsehub
#
# Refer: https;//udemy.com/course/data-project-with-beautiful-soup-web-scraping-e-commerce/learn/lecture/28122518 #overview

# %%
pip install beautifulsoup4
# Out:
# Requirement already satisfied: beautifulsoup4 in c:\users\dell\anaconda3\lib\site-packages (4.9.3)Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: soupsieve>1.2 in c:\users\dell\anaconda3\lib\site-packages (from beautifulsoup4) (2.2.1)

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
from lxml import html

# %%
website ='https://www.jumia.com.ng/electronics-accessories/'

# %%
website
# Out:
# 'https://www.jumia.com.ng/electronics-accessories/'

# %% [markdown]
# ## GET REQUEST

# %%
me = requests.get(website)

# %% [markdown]
# ## Status Code

# %%
me.status_code
# Out:
# 200

# %% [markdown]
# ### Soup

# %%
soup = BeautifulSoup(me.content, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en"><head><meta charset="utf-8"/><title>Electronics Here - Buy Electronics Accessories | Jumia Nigeria</title><meta content="product" property="og:type"/><meta content="Jumia Nigeria" property="og:site_name"/><meta content="Electronics Here - Buy Electronics Accessories | Jumia Nigeria" property="og:title"/><meta content="Shop from Biggest Electronics Accessories Collection Today - Best Electronics Online from Jumia Nigeria | Fast Delivery - Free Returns" property="og:description"/><meta content="/electronics-accessories/" property="og:url"/><meta content="https://ng.jumia.is/cms/jumialogonew.png" property="og:image"/><meta content="en_NG" property="og:locale"/><meta content="Electronics Here - Buy Electronics Accessories | Jumia Nigeria" name="title"/><meta content="index, follow" name="robots"/><meta content="Shop from Biggest Electronics Accessories Collection Today - Best Electronics Online from Jumia Nigeria | Fast Delivery - Free Returns" name="description"/><link href="android-app://com.jumia.android/JUMIA/NG/c/electronics-accessories?utm_source=google&amp;utm_medium=organic&amp;adjust_tracker=j1hd8h&amp;adjust_campaign=GOOGLE_SEARCH&amp;adjust_adgroup=https%3A%2F%2Fwww.jumia.com.ng%2Felectronics-accessories%2F" rel="alternate"/><link href="https://www.jumia.com.ng/electronics-accessories/" rel="canonical"/><link href="https://www.jumia.com.ng/electronics-accessories/?page=2" rel="next"/><meta content="728795990650684" property="fb:app_id"/><meta content="291297097615087" property="fb:pages"/><meta content="4vr0StQ8YkyEzgDxkC_mgx0UMSH2xM3vkOaRpaMEjWM" name="google-site-verification"/><meta content="66DCE7076C4C56245BAB83C687510491" name="msvalidate.01"/><meta content="width=device-width, initial-scale=1.0" name="viewport"/><link href="https://www.jumia.com.ng/assets_he/css/main.1f1af2d1.css" rel="stylesheet"/><link href="https://www.jumia.com.ng/assets_he/favicon.dbe4090f.ico" rel="icon" type="image/ico"/><link href="//bam.nr-data.net" rel="preconnect dns-prefetch"/><link href="//js-agent.newrelic.com" rel="preconnect dns-prefetch"/><link href="//www.google-analytics.com" rel="preconnect dns-prefetch"/><link href="//www.googletagmanager.com" rel="preconnect dns-prefetch"/><link href="//www.facebook.com" rel="preconnect dns-prefetch"/><link href="//connect.facebook.net" rel="preconnect dns-prefetch"/><link href="//static.criteo.net" rel="preconnect dns-prefetch"/><link href="//sslwidget.criteo.com" rel="preconnect dns-prefetch"/><link href="//dis.eu.criteo.com" rel="preconnect dns-prefetch"/><link href="//creativecdn.com" rel="preconnect dns-prefetch"/><link href="https://ng.jumia.is" rel="dns-prefetch"/></head><body><script type="text/javascript">window.NREUM||(NREUM={});NREUM.info = {"agent":"","beacon":"bam-cell.nr-data.net","errorBeacon":"bam-cell.nr-data.net","licenseKey":"b76de0635f","applicationID":"202020352","applicationTime":13.021639,"transactionName":"NVxXYhMHChFYVUELDQwWdkMSEgsPFnVUFgMOVlIWHUY0LWpi","queueTime":0,"ttGuid":"0b574fde7b03f3fb","agentToken":null}; (window.NREUM||(NREUM={})).init={ajax:{deny_list:["bam-cell.nr-data.net"]}};(window.NREUM||(NREUM={})).loader_config={licenseKey:"b76de0635f",applicationID:"202020352"};window.NREUM||(NREUM={}),__nr_require=function(t,e,n){function r(n){if(!e[n]){var i=e[n]={exports:{}};t[n][0].call(i.exports,function(e){var i=t[n][1][e];return r(i||e)},i,i.exports)}return e[n].exports}if("function"==typeof __nr_require)return __nr_require;for(var i=0;i<n.length;i++)r(n[i]);return r}({1:[function(t,e,n){function r(){}function i(t,e,n,r){return function(){return s.recordSupportability("API/"+e+"/called"),o(t+e,[u.now()].concat(c(arguments)),n?null:this,r),n?void 0:this}}var o=t("handle"),a=t(10),c=t(11),f=t("ee").get("tracer"),u=t("loader"),s=t(4),d=NREUM;"undefined"==typeof window.newrelic&&(newrelic=d);var p=["setPageViewName","setCustomAttribute","setErrorHandler","finished","addToTrace","inlineHit","addRelease"],l="api-",v=l+"ixn-";a(p,function ...

# %%
# We need to store the result inside a variable
# We want to get access to all the html elements first
# I want to store the list results inside a variable

me = soup.find_all ('article',{'class': 'prd _fb col c-prd'})

# %%
len(me)
# Out:
# 40

# %%
# Using index, we'll try to print out the first value in me

# %%
me[0:40]
# Out:
# [<article class="prd _fb col c-prd"><a class="core" data-brand="Generic" data-category="Electronics/Accessories/Gadgets" data-dimension23="283590" data-dimension26="4" data-dimension27="4.8" data-dimension28="0" data-dimension37="0" data-dimension43="" data-dimension44="0" data-id="GE779EL15H0MSNAFAMZ" data-list="" data-name="Security Metal Detector Garrett" data-position="1" data-price="14.20" data-track-onclick="eecProduct" data-track-onview="eecProduct" href="/generic-security-metal-detector-garrett-82285696.html"><div class="img-c"><img alt="" class="img" data-lazy="" data-src="https://ng.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/69/658228/1.jpg?7708" height="208" src="..." width="208"/></div><div class="info"><h3 class="name">Security Metal Detector Garrett</h3><div class="prc">₦ 6,500</div><div class="s-prc-w"><div class="old">₦ 9,000</div><div class="tag _dsct _sm">28%</div></div><div class="rev"><div class="stars _s">4.8 out of 5<div class="in" style="width:96%"></div></div>(4)</div></div></a><footer class="ft"><form action="/cart/products/GE779EL15H0MSNAFAMZ-112619067/quantity/" class="-df -i-ctr -pr -j-bet" data-add-cart="" data-brand="Generic" data-category="Electronics/Accessories/Gadgets" data-dimension23="283590" data-dimension26="4" data-dimension27="4.8" data-dimension28="0" data-dimension37="0" data-dimension43="" data-dimension44="0" data-id="GE779EL15H0MSNAFAMZ" data-name="Security Metal Detector Garrett" data-price="14.20" data-simplesku="GE779EL15H0MSNAFAMZ-112619067" data-sku="GE779EL15H0MSNAFAMZ" data-svar="GE779EL15H0MSNAFAMZ-112619067" data-track-onsubmit="addToCart" data-variant="" data-xhr="" method="post"><button class="add btn _prim -pea _md" data-submit="" name="action" type="button" value="in">Add To Cart</button><input name="csrfToken" type="hidden" value="8803343367b5e6963475577f45310df4"/></form></footer></article>,
#  <article class="prd _fb col c-prd"><a class="core" data-brand="ZTE" data-category="Electronics/Accessories/Gadgets" data-dimension23="49044" data-dimension26="" data-dimension27="" data-dimension28="0" data-dimension37="0" data-dimension43="" data-dimension44="0" data-id="ZT786EA0PTSHWNAFAMZ" data-list="" data-name="Universal Mobile 3G/4G Wifi / Mifi" data-position="2" data-price="56.36" data-track-onclick="eecProduct" data-track-onview="eecProduct" href="/zte-universal-mobile-3g4g-wifi-mifi-65308334.html"><div class="img-c"><img alt="" class="img" data-lazy="" data-src="https://ng.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/43/380356/1.jpg?6626" height="208" src="..." width="208"/></div><div class="info"><h3 class="name">ZTE Universal Mobile 3G/4G Wifi / Mifi</h3><div class="prc">₦ 25,790</div><div class="s-prc-w"><div class="old">₦ 32,000</div><div class="tag _dsct _sm">19%</div></div></div></a><footer class="ft"><form action="/cart/products/ZT786EA0PTSHWNAFAMZ-91476054/quantity/" class="-df -i-ctr -pr -j-bet" data-add-cart="" data-brand="ZTE" data-category="Electronics/Accessories/Gadgets" data-dimension23="49044" data-dimension26="" data-dimension27="" data-dimension28="0" data-dimension37="0" data-dimension43="" data-dimension44="0" data-id="ZT786EA0PTSHWNAFAMZ" data-name="Universal Mobile 3G/4G Wifi / Mifi" data-price="56.36" data-simplesku="ZT786EA0PTSHWNAFAMZ-91476054" data-sku="ZT786EA0PTSHWNAFAMZ" data-svar="ZT786EA0PTSHWNAFAMZ-91476054" data-track-onsubmit="addToCart" data-variant="" data-xhr="" method="post"><button class="add btn _prim -pea _md" data-submit="" name="action" type="button" value="in">Add To Cart</button><input name="csrfToken" type="hidden" value="8803343367b5e6963475577f45310df4"/></form></footer></article>,
#  <article class="prd _fb col c-prd"><a class="core" data-brand="Generic" data-category="Electronics/Accessories/Gadgets" data-dimension23="319233" data-dimension26="" data-dimension27="" data-dimension28="0" data-dimension37="0" data-dimension43="" data-dimension44="0" data-id="GE779EA1D1XALNAFAMZ" data-list="" data-name="TV STREAMING DEVICE CHROME CAST" data-position="3" data-price="18.57" data-track-onclick="eecProduct" data-track-onview="eecProduct" href="/generic-tv-streaming-device-chrome-cast-98909328.html"><div class="img-c"><img alt="" class="img" data-lazy="" data-src="https://ng.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/82/390989/1.jpg?7073" height="208" src="..." width="208"/></div><div class="info"><h3 class="name">TV STREAMING DEVICE CHROME CAST</h3><div class="prc">₦ 8,500</div></div></a><footer class="ft"><form action="/cart/products/GE779EA1D1XALNAFAMZ-135924048/quantity/" class="-df -i-ctr -pr -j-bet" data-add-cart="" data-brand="Generic" data-category="Electronics/Accessories/Gadgets" data-dimension23="319233" data-dimension26="" data-dimension27="" data-dimension28="0" data-dimension37="0" data-dimension43="" data-dimension44="0" data-id="GE779EA1D1XALNAFAMZ" data-name="TV STREAMING DEVICE CHROME CAST" data-price="18.57" data-simplesku="GE779EA1D1XALNAFAMZ-135924048" data-sku="GE779EA1D1XALNAFAMZ" data-svar="GE779EA1D1XALNAFAMZ-135924048" data-track-onsubmit="addToCart" data-variant="" data-xhr="" method="post"><button class="add btn _prim -pea _md" data-submit="" name="action" type="button" value="in">Add To Cart</button><input name="csrfToken" type="hidden" value="8803343367b5e6963475577f45310df4"/></form></footer></article>,
#  <article class="prd _fb col c-prd"><a class="core" data-brand="ZTE" data-category="Electronics/Accessories/Gadgets" data-dimension23="218569" data-dimension26="6" data-dimension27="4.2" data-dimension28="0" data-dimension37="0" data-dimension43="" data-dimension44="0" data-id="ZT786EA0408V8NAFAMZ" data-list="" data-name="Universal Mobile 3G/4G Wifi / Mifi" data-position="4" data-price="60.97" data-track-onclick="eecProduct" data-track-onview="eecProduct" href="/zte-universal-mobile-3g4g-wifi-mifi-65992760.html"><div class="img-c"><img alt="" class="img" data-lazy="" data-src="https://ng.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/06/729956/1.jpg?5825" height="208" src="..." width="208"/></div><div class="info"><h3 class="name">ZTE Universal Mobile 3G/4G Wifi / Mifi</h3><div class="prc">₦ 27,900</div><div class="s-prc-w"><div class="old">₦ 35,900</div><div class="tag _dsct _sm">22%</div></div><div class="rev"><div class="stars _s">4.2 out of 5<div class="in" style="width:84%"></div></div>(6)</div></div></a><footer class="ft"><form action="/cart/products/ZT786EA0408V8NAFAMZ-92538637/quantity/" class="-df -i-ctr -pr -j-bet" data-add-cart="" data-brand="ZTE" data-category="Electronics/Accessories/Gadgets" data-dimension23="218569" data-dimension26="6" data-dimension27="4.2" data-dimension28="0" data-dimension37="0" data-dimension43="" data-dimension44="0" data-id="ZT786EA0408V8NAFAMZ" data-name="Universal Mobile 3G/4G Wifi / Mifi" data-price="60.97" data-simplesku="ZT786EA0408V8NAFAMZ-92538637" data-sku="ZT786EA0408V8NAFAMZ" data-svar="ZT786EA0408V8NAFAMZ-92538637" data-track-onsubmit="addToCart" data-variant="" data-xhr="" method="post"><button class="add btn _prim -pea _md" data-submit="" name="action" type="button" value="in">Add To Cart</button><input name="csrfToken" type="hidden" value="8803343367b5e6963475577f45310df4"/></form></footer></article>,
#  <article class="prd _fb col c-prd"><a class="core" data-brand="Generic" data-category="Electronics/Accessories/Gadgets" data-dimension23="252280" data-dimension26="1" data-dimension27="4" data-dimension28="0" data-dimension37="0" data-dimension43="" data-dimension44="0" data-id="GE779EA0F4JK9NAFAMZ" data-list="" data-name="AirPods Case Cover For Apple AirPods 2" data-position="5" data-price="5.46" data-track-onclick="eecProduct" data-track-onview="eecProduct" href="/generic-airpods-case-cover-for-apple-airpods-2-71260452.html"><div class="img-c"><img alt="" class="img" data-lazy="" data-src="https://ng.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/25/406217/1.jpg?3026" height="208" src="..." width="208"/></div><div class="info"><h3 class="name">AirPods Case Cover For Apple AirPods 2</h3><div class="prc">₦ 2,500</div><div class="rev"><div class="stars _s">4 out of 5<div class="in" style="width:80%"></div></div>(1)</div></div></a><footer class="ft"><form action="/cart/products/GE779EA0F4JK9NAFAMZ-99413605/quantity/" class="-df -i-ctr -pr -j-bet" data-add-cart="" data-brand="Generic" data-category="Electronics/Accessories/Gadgets" data-dimension23="252280" data-dimension26="1" data-dimension27="4" data-dimension28="0" data-dimension37="0" data-dimension43="" data-dimension44="0" data-id="GE779EA0F4JK9NAFAMZ" data-name="AirPods Case Cover For Apple AirPods 2" data-price="5.46" data-simplesku="GE779EA0F4JK9NAFAMZ-99413605" data-sku="GE779EA0F4JK9NAFAMZ" data-svar="GE779EA0F4JK9NAFAMZ-99413605" data-track-onsubmit="addToCart" data-variant="" data-xhr="" method="post"><button class="add btn _prim -pea _md" data-submit="" name="action" type="button" value="in">Add To Cart</button><input name="csrfToken" type="hidden" value="8803343367b5e6963475577f45310df4"/></form></footer></article>,
#  <article class="prd _fb col c-prd"><a class="core" data-brand="Generic" data-category="Electronics/Accessories/Gadgets" data-dimension23="20544" data-dimension26="" data-dimension27="" data-dimension28="0" data-dimension37="0" data-dimension43="" data-dimension44="0" data-id="GE779EL1KC96CNAFAMZ" data-list="" data-name="HD USB Hidden Camera Pen Video Security Camera DVR" data-position="6" data-price="14.20" data-track-onclick="eecProduct" data-track-onview="eecProduct" href="/8gb-hd-usb-spy-pen-video-security-camera-dvr-generic-mpg98178.html"><div class="img-c"><img alt="" class="img" data-lazy="" data-src="https://ng.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/94/63026/1.jpg?9078" height="208" src="..." width="208"/></div><div class="info"><h3 class="name">HD USB Hidden Camera Pen Video Security Camera DVR</h3><div class="prc">₦ 6,500</div></div></a><footer class="ft"><form action="/cart/products/GE779EL1KC96CNAFAMZ-4448333/quantity/" class="-df -i-ctr -pr -j-bet" data-add-cart="" data-brand="Generic" data-category="Electronics/Accessories/Gadgets" data-dimension23="20544" data-dimension26="" data-dimension27="" data-dimension28="0" data-dimension37="0" data-dimension43="" data-dimension44="0" data-id="GE779EL1KC96CNAFAMZ" data-name="HD USB Hidden Camera Pen Video Security Camera DVR" data-price="14.20" data-simplesku="GE779EL1KC96CNAFAMZ-4448333" data-sku="GE779EL1KC96CNAFAMZ" data-svar="GE779EL1KC96CNAFAMZ-4448333" data-track-onsubmit="addToCart" data-variant="" data-xhr="" method="post"><button class="add btn _prim -pea _md" data-submit="" name="action" type="button" value="in">Add To Cart</button><input name="csrfToken" type="hidden" value="8803343367b5e6963475577f45310df4"/></form></footer></article>,
#  <article class="prd _fb col c-prd"><a class="core" data-brand="Generic" data-category="Electronics/Accessories/Gadgets" data-dimension23="138048" data-dimension26="" data-dimension27="" data-dimension28="0" data-dimension37="1" data-dimension43="" data-dimension44="0" data-id="GE779EL11NCGSNAFAMZ" data-list="" data-name="Fireproof Explosionproof Lipo Battery Safe Bag" data-position="7" data-price="12.89" data-track-onclick="eecProduct" data-track-onview="eecProduct" href="/generic-fireproof-explosionproof-lipo-battery-safe-bag-63053236.html"><div class="img-c"><img alt="" class="img" data-lazy="" data-src="https://ng.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/63/235036/1.jpg?5599" height="208" src="..." width="208"/></div><div class="info"><div class="tag _glb _sm">Shipped from abroad</div><h3 class="name">Fireproof Explosionproof Lipo Battery Safe Bag</h3><div class="prc">₦ 5,900</div><div class="s-prc-w"><div class="old">₦ 8,850</div><div class="tag _dsct _sm">33%</div></div></div></a><footer class="ft"><div class="-df -i-ctr -pr -j-bet" data-add-cart="" data-sku="GE779EL11NCGSNAFAMZ" data-svar="GE779EL11NCGSNAFAMZ-87780532" data-xhr=""><button class="add btn _prim -pea _md" data-trigpopup="" type="button">Add To Cart</button></div></footer></article>,
#  <article class="prd _fb col c-prd"><a class="core" data-brand="Generic" data-category="Electronics/Accessories/Gadgets" data-dimension23="28443" data-dimension26="4" data-dimension27="4.5" data-dimension28="0" data-dimension37="0" data-dimension43="" data-dimension44="0" data-id="UN970HL0K82F1NAFAMZ" data-list="" data-name="Security Baton Flash Light" data-position="8" data-price="32.45" data-track-onclick="eecProduct" data-track-onview="eecProduct" href="/security-baton-flash-light-universal-mpg166067.html"><div class="img-c"><img alt="" class="img" data-lazy="" data-src="https://ng.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/33/968701/1.jpg?0528" height="208" src="..." width="208"/></div><div class="info"><h3 class="name">Security Baton Flash Light</h3><div class="prc">₦ 14,850</div><p class="mpg" data-prc="₦ 14,850" data-tot="2">offers from</p><div class="rev"><div class="stars _s">4.5 out of 5<div class="in" style="width:90%"></div></div>(4)</div></div></a><footer class="ft"><form action="/cart/products/UN970HL0K82F1NAFAMZ-10857715/quantity/" class="-df -i-ctr -pr -j-bet" data-add-cart="" data-brand="Generic" data-category="Electronics/Accessories/Gadgets" data-dimension23="28443" data-dimension26="4" data-dimension27="4.5" data-dimension28="0" data-dimension37="0" data-dimension43="" data-dimension44="0" data-id="UN970HL0K82F1NAFAMZ" data-name="Security Baton Flash Light" data-price="32.45" data-simplesku="UN970HL0K82F1NAFAMZ-10857715" data-sku="UN970HL0K82F1NAFAMZ" data-svar="UN970HL0K82F1NAFAMZ-10857715" data-track-onsubmit="addToCart" data-variant="" data-xhr="" method="post"><button class="add btn _prim -pea _md" data-submit="" name="action" type="button" value="in">Add To Cart</button><input name="csrfToken" type="hidden" value="8803343367b5e6963475577f45310df4"/></form></footer></article>,
#  <article class="prd _fb col c-prd"><a class="core" data-brand="Generic" data-category="Electronics/Accessories/Gadgets" data-dimension23="119175" data-dimension26="1" data-dimension27="4" data-dimension28="0" data-dimension37="1" data-dimension43="" data-dimension44="0" data-id="GE779EL066RGONAFAMZ" data-list="" data-name="RC 2200KV Brushless Motor 2212-6 + 30A ESC Helicopter DIY" data-position="9" data-price="17.55" data-track-onclick="eecProduct" data-track-onview="eecProduct" href="/generic-rc-2200kv-brushless-motor-2212-6-30a-esc-helicopter-diy-42239301.html"><div class="img-c"><img alt="" class="img" data-lazy="" data-src="https://ng.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/10/393224/1.jpg?7160" height="208" src="..." width="208"/></div><div class="info"><div class="tag _glb _sm">Shipped from abroad</div><h3 class="name">RC 2200KV Brushless Motor 2212-6 + 30A ESC Helicopter DIY</h3><div class="prc">₦ 8,033</div><div class="s-prc-w"><div class="old">₦ 14,017</div><div class="tag _dsct _sm">43%</div></div><div class="rev"><div class="stars _s">4 out of 5<div class="in" style="width:80%"></div></div>(1)</div></div></a><footer class="ft"><form action="/cart/products/GE779EL066RGONAFAMZ-58863991/quantity/" class="-df -i-ctr -pr -j-bet" data-add-cart="" data-brand="Generic" data-category="Electronics/Accessories/Gadgets" data-dimension23="119175" data-dimension26="1" data-dimension27="4" data-dimension28="0" data-dimension37="1" data-dimension43="" data-dimension44="0" data-id="GE779EL066RGONAFAMZ" data-name="RC 2200KV Brushless Motor 2212-6 + 30A ESC Helicopter DIY" data-price="17.55" data-simplesku="GE779EL066RGONAFAMZ-58863991" data-sku="GE779EL066RGONAFAMZ" data-svar="GE779EL066RGONAFAMZ-58863991" data-track-onsubmit="addToCart" data-variant="" data-xhr="" method="post"><button class="add btn _prim -pea _md" data-submit="" name="action" type="button" value="in">Add To Cart</button><input name="csrfToken" type="hidden" value="8803343367b5e6963475577f45310df4"/></form></footer></article>,
#  <article class="prd _fb col c-prd"><a class="core" data-brand="Oraimo" data-category="Electronics/Accessories/Gadgets" data-dimension23="110870" data-dimension26="2" data-dimension27="5" data-dimension28="0" data-dimension37="0" data-dimension43="" data-dimension44="0" data-id="OR537EA0DN8U3NAFAMZ" data-list="" data-name="OCD-T61 2in1 Type C &amp; Micro USB Charging Cable" data-position="10" data-price="6.12" data-track-onclick="eecProduct" data-track-onview="eecProduct" href="/oraimo-ocd-t61-2in1-type-c-micro-usb-charging-cable-74591922.html"><div class="img-c"><img alt="" class="img" data-lazy="" data-src="https://ng.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/22/919547/1.jpg?6433" height="208" src="..." width="208"/></div><div class="info"><h3 class="name">Oraimo OCD-T61 2in1 Type C &amp; Micro USB Charging Cable</h3><div class="prc">₦ 2,800</div><div class="rev"><div class="stars _s">5 out of 5<div class="in" style="width:100%"></div></div>(2)</div></div></a><footer class="ft"><form action="/cart/products/OR537EA0DN8U3NAFAMZ-103283971/quantity/" class="-df -i-ctr -pr -j-bet" data-add-cart="" data-brand="Oraimo" data-category="Electronics/Accessories/Gadgets" data-dimension23="110870" data-dimension26="2" data-dimension27="5" data-dimension28="0" data-dimension37="0" data-dimension43="" data-dimension44="0" data-id="OR537EA0DN8U3NAFAMZ" data-name="OCD-T61 2in1 Type C &amp; Micro USB Charging Cable" data-price="6.12" data-simplesku="OR537EA0DN8U3NAFAMZ-103283971" data-sku="OR537EA0DN8U3NAFAMZ" data-svar="OR537EA0DN8U3NAFAMZ-103283971" data-track-onsubmit="addToCart" data-variant="" data-xhr="" method="post"><button class="add btn _prim -pea _md" data-submit="" name="action" type="button" value="in">Add To Cart</button><input name="csrfToken" type="hidden" value="8803343367b5e6963475577f45310df4"/></form></footer></article>,
#  <article class="prd _fb col c-prd"><a class="core" data-brand="Longrich" data-category="Electronics/Accessories/Gadgets" data-dimension23="215083" data-dimension26="" data-dimension27="" data-dimension28="0" data-dimension37="0" data-dimension43="" data-dimension44="0" data-id="LO095EL11LJ3GNAFAMZ" data-list="" data-name="Classic, Durable Powerbank Charger(Stays Long Hours) - White" data-position="11" data-price="39.33" data-track-onclick="eecProduct" data-track-onview="eecProduct" href="/longrich-classic-durable-powerbank-chargerstays-long-hours-white-61305136.html"><div class="img-c"><img alt="" class="img" data-lazy="" data-src="https://ng.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/63/150316/1.jpg?4126" height="208" src="..." width="208"/></div><div class="info"><h3 class="name">Longrich Classic, Durable Powerbank Charger(Stays Long Hours) - White</h3><div class="prc">₦ 18,000</div></div></a><footer class="ft"><div class="-df -i-ctr -pr -j-bet" data-add-cart="" data-sku="LO095EL11LJ3GNAFAMZ" data-svar="LO095EL11LJ3GNAFAMZ-85400687" data-xhr=""><button class="add btn _prim -pea _md" data-trigpopup="" type="button">Add To Cart</button></div></footer></article>,
#  <article class="prd _fb col c-prd"><a class="core" data-brand="Bosto" data-category="Electronics/Accessories/Gadgets" data-dimension23="138048" data-dimension26="" data-dimension27="" data-dimension28="0" data-dimension37="1" data-dimension43="" data-dimension44="0" data-id="GE779EL088RGMNAFAMZ" data-list="" data-name="1060 Plus Digital Graphic Drawing Painting Animation" data-position="12" data-price="31.93" data-track-onclick="eecProduct" data-track-onview="eecProduct" href="/bosto-1060-plus-digital-graphic-drawing-painting-animation-66754831.html"><div class="img-c"><img alt="" class="img" data-lazy="" data-src="https://ng.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/13/845766/1.jpg?5967" height="208" src="..." width="208"/></div><div class="info"><div class="tag _glb _sm">Shipped from abroad</div><h3 class="name">Bosto 1060 Plus Digital Graphic Drawing Painting Animation</h3><div class="prc">₦ 14,610</div><div class="s-prc-w"><div class="old">₦ 21,915</div><div class="tag _dsct _sm">33%</div></div></div></a><footer class="ft"><div class="-df -i-ctr -pr -j-bet" data-add-cart="" data-sku="GE779EL088RGMNAFAMZ" data-svar="GE779EL088RGMNAFAMZ-93510202" data-xhr=""><button class="add btn _prim -pea _md" data-trigpopup="" type="button">Add To Cart</button></div></footer></article>,
#  <article class="prd _fb col c-prd"><a class="core" data-brand="Generic" data-category="Electronics/Accessories/Gadgets" data-dimension23="99868" data-dimension26="6" data-dimension27="4.7" data-dimension28="0" data-dimension37="0" data-dimension43="DOW_73" data-dimension44="0" data-id="GE779EL068MUINAFAMZ" data-list="" data-name="Security Metal Detector Garrett" data-position="13" data-price="15.30" data-track-onclick="eecProduct" data-track-onview="eecProduct" href="/security-metal-detector-garrett-generic-mpg1225982.html"><div class="img-c"><img alt="" class="img" data-lazy="" data-src="https://ng.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/10/480554/1.jpg?4838" height="208" src="..." width="208"/></div><div class="info"><h3 class="name">Security Metal Detector Garrett</h3><div class="prc">₦ 7,000</div><div class="s-prc-w"><div class="old">₦ 8,500</div><div class="tag _dsct _sm">18%</div></div><div class="rev"><div class="stars _s">4.7 out of 5<div class="in" style="width:94%"></div></div>(6)</div></div></a><footer class="ft"><form action="/cart/products/GE779EL068MUINAFAMZ-64614722/quantity/" class="-df -i-ctr -pr -j-bet" data-add-cart="" data-brand="Generic" data-category="Electronics/Accessories/Gadgets" data-dimension23="99868" data-dimension26="6" data-dimension27="4.7" data-dimension28="0" data-dimension37="0" data-dimension43="DOW_73" data-dimension44="0" data-id="GE779EL068MUINAFAMZ" data-name="Security Metal Detector Garrett" data-price="15.30" data-simplesku="GE779EL068MUINAFAMZ-64614722" data-sku="GE779EL068MUINAFAMZ" data-svar="GE779EL068MUINAFAMZ-64614722" data-track-onsubmit="addToCart" data-variant="" data-xhr="" method="post"><button class="add btn _prim -pea _md" data-submit="" name="action" type="button" value="in">Add To Cart</button><input name="csrfToken" type="hidden" value="8803343367b5e6963475577f45310df4"/></form></footer></article>,
#  <article class="prd _fb col c-prd"><a class="core" data-brand="Generic" data-category="Electronics/Accessories/Gadgets" data-dimension23="291977" data-dimension26="" data-dimension27="" data-dimension28="0" data-dimension37="0" data-dimension43="" data-dimension44="0" data-id="GE779EL27GLZENAFAMZ" data-list="" data-name="Security Tactical Jacket" data-position="14" data-price="39.33" data-track-onclick="eecProduct" data-track-onview="eecProduct" href="/generic-security-tactical-jacket-105646433.html"><div class="img-c"><img alt="" class="img" data-lazy="" data-src="https://ng.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/33/4646501/1.jpg?3385" height="208" src="..." width="208"/></div><div class="info"><h3 class="name">Security Tactical Jacket</h3><div class="prc">₦ 17,999</div></div></a><footer class="ft"><form action="/cart/products/GE779EL27GLZENAFAMZ-144362212/quantity/" class="-df -i-ctr -pr -j-bet" data-add-cart="" data-brand="Generic" data-category="Electronics/Accessories/Gadgets" data-dimension23="291977" data-dimension26="" data-dimension27="" data-dimension28="0" data-dimension37="0" data-dimension43="" data-dimension44="0" data-id="GE779EL27GLZENAFAMZ" data-name="Security Tactical Jacket" data-price="39.33" data-simplesku="GE779EL27GLZENAFAMZ-144362212" data-sku="GE779EL27GLZENAFAMZ" data-svar="GE779EL27GLZENAFAMZ-144362212" data-track-onsubmit="addToCart" data-variant="" data-xhr="" method="post"><button class="add btn _prim -pea _md" data-submit="" name="action" type="button" value="in">Add To Cart</button><input name="csrfToken" type="hidden" value="8803343367b5e6963475577f45310df4"/></form></footer></article>,
#  <article class="prd _fb col c-prd"><a class="core" data-brand="Wacom" data-category="Electronics/Accessories/Gadgets" data-dimension23="13560" data-dimension26="" data-dimension27="" data-dimension28="0" data-dimension37="0" data-dimension43="" data-dimension44="0" data-id="WA402EA0UZ4XONAFAMZ" data-list="" data-name="Bamboo Folio Smart Pad, Small, Dark Gray" data-position="15" data-price="131.11" data-track-onclick="eecProduct" data-track-onview="eecProduct" href="/wacom-bamboo-folio-smart-pad-small-dark-gray-63872025.html"><div class="img-c"><img alt="" class="img" data-lazy="" data-src="https://ng.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/52/027836/1.jpg?3151" height="208" src="..." width="208"/></div><div class="info"><h3 class="name">Wacom Bamboo Folio Smart Pad, Small, Dark Gray</h3><div class="prc">₦ 60,000</div></div></a><footer class="ft"><form action="/cart/products/WA402EA0UZ4XONAFAMZ-89245110/quantity/" class="-df -i-ctr -pr -j-bet" data-add-cart="" data-brand="Wacom" data-category="Electronics/Accessories/Gadgets" data-dimension23="13560" data-dimension26="" data-dimension27="" data-dimension28="0" data-dimension37="0" data-dimension43="" data-dimension44="0" data-id="WA402EA0UZ4XONAFAMZ" data-name="Bamboo Folio Smart Pad, Small, Dark Gray" data-price="131.11" data-simplesku="WA402EA0UZ4XONAFAMZ-89245110" data-sku="WA402EA0UZ4XONAFAMZ" data-svar="WA402EA0UZ4XONAFAMZ-89245110" data-track-onsubmit="addToCart" data-variant="" data-xhr="" method="post"><button class="add btn _prim -pea _md" data-submit="" name="action" type="button" value="in">Add To Cart</button><input name="csrfToken" type="hidden" value="8803343367b5e6963475577f45310df4"/></form></footer></article>,
#  <article class="prd _fb col c-prd"><a class="core" data-brand="Generic" data-category="Electronics/Accessories/Gadgets" data-dimension23="111949" data-dimension26="" data-dimension27="" data-dimension28="0" data-dimension37="0" data-dimension43="" data-dimension44="0" data-id="GE779EA1K6PXENAFAMZ" data-list="" data-name="PANAROMIC 360° CCTV CAMERA WIDE ANGLE COVERAGE (1pcs)" data-position="16" data-price="28.41" data-track-onclick="eecProduct" data-track-onview="eecProduct" href="/generic-panaromic-360-cctv-camera-wide-angle-coverage-1pcs-43027349.html"><div class="img-c"><img alt="" class="img" data-lazy="" data-src="https://ng.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/94/372034/1.jpg?2261" height="208" src="..." width="208"/></div><div class="info"><h3 class="name">PANAROMIC 360° CCTV CAMERA WIDE ANGLE COVERAGE (1pcs)</h3><div class="prc">₦ 13,000</div><div class="s-prc-w"><div class="old">₦ 35,000</div><div class="tag _dsct _sm">63%</div></div></div></a><footer class="ft"><form action="/cart/products/GE779EA1K6PXENAFAMZ-60178718/quantity/" class="-df -i-ctr -pr -j-bet" data-add-cart="" data-brand="Generic" data-category="Electronics/Accessories/Gadgets" data-dimension23="111949" data-dimension26="" data-dimension27="" data-dimension28="0" data-dimension37="0" data-dimension43="" data-dimension44="0" data-id="GE779EA1K6PXENAFAMZ" data-name="PANAROMIC 360° CCTV CAMERA WIDE ANGLE COVERAGE (1pcs)" data-price="28.41" data-simplesku="GE779EA1K6PXENAFAMZ-60178718" data-sku="GE779EA1K6PXENAFAMZ" data-svar="GE779EA1K6PXENAFAMZ-60178718" data-track-onsubmit="addToCart" data-variant="" data-xhr="" method="post"><button class="add btn _prim -pea _md" data-submit="" name="action" type="button" value="in">Add To Cart</button><input name="csrfToken" type="hidden" value="8803343367b5e6963475577f45310df4"/></form></footer></article>,
#  <article class="prd _fb col c-prd"><a class="core" data-brand="Generic" data-category="Electronics/Accessories/Gadgets" data-dimension23="179804" data-dimension26="" data-dimension27="" data-dimension28="0" data-dimension37="0" data-dimension43="" data-dimension44="0" data-id="RE909EA0G8KPKNAFAMZ" data-list="" data-name="Dstv Universal Dstv Standard Decoder Remote Control" data-position="17" data-price="5.14" data-track-onclick="eecProduct" data-track-onview="eecProduct" href="/generic-dstv-universal-dstv-standard-decoder-remote-control-44937272.html"><div class="img-c"><img alt="" class="img" data-lazy="" data-src="https://ng.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/27/273944/1.jpg?2424" height="208" src="..." width="208"/></div><div class="info"><h3 class="name">Dstv Universal Dstv Standard Decoder Remote Control</h3><div class="prc">₦ 2,350</div><div class="s-prc-w"><div class="old">₦ 5,000</div><div class="tag _dsct _sm">53%</div></div></div></a><footer class="ft"><form action="/cart/products/RE909EA0G8KPKNAFAMZ-63660620/quantity/" class="-df -i-ctr -pr -j-bet" data-add-cart="" data-brand="Generic" data-category="Electronics/Accessories/Gadgets" data-dimension23="179804" data-dimension26="" data-dimension27="" data-dimension28="0" data-dimension37="0" data-dimension43="" data-dimension44="0" data-id="RE909EA0G8KPKNAFAMZ" data-name="Dstv Universal Dstv Standard Decoder Remote Control" data-price="5.14" data-simplesku="RE909EA0G8KPKNAFAMZ-63660620" data-sku="RE909EA0G8KPKNAFAMZ" data-svar="RE909EA0G8KPKNAFAMZ-63660620" data-track-onsubmit="addToCart" data-variant="" data-xhr="" method="post"><button class="add btn _prim -pea _md" data-submit="" name="action" type="button" value="in">Add To Cart</button><input name="csrfToken" type="hidden" value="8803343367b5e6963475577f45310df4"/></form></footer></article>,
#  <article class="prd _fb col c-prd"><a class="core" data-brand="Generic" data-category="Electronics/Accessories/Gadgets" data-dimension23="161548" data-dimension26="2" data-dimension27="4" data-dimension28="0" data-dimension37="0" data-dimension43="" data-dimension44="0" data-id="GE779EL11V8YENAFAMZ" data-list="" data-name="Shirt Button Camera Pinhole Mini Dv Dvr Voice Video Recorder" data-position="18" data-price="21.85" data-track-onclick="eecProduct" data-track-onview="eecProduct" href="/generic-shirt-button-camera-pinhole-mini-dv-dvr-voice-video-recorder-43730636.html"><div class="img-c"><img alt="" class="img" data-lazy="" data-src="https://ng.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/63/603734/1.jpg?4478" height="208" src="..." width="208"/></div><div class="info"><h3 class="name">Shirt Button Camera Pinhole Mini Dv Dvr Voice Video Recorder</h3><div class="prc">₦ 9,999</div><div class="s-prc-w"><div class="old">₦ 19,999</div><div class="tag _dsct _sm">50%</div></div><div class="rev"><div class="stars _s">4 out of 5<div class="in" style="width:80%"></div></div>(2)</div></div></a><footer class="ft"><form action="/cart/products/GE779EL11V8YENAFAMZ-61594144/quantity/" class="-df -i-ctr -pr -j-bet" data-add-cart="" data-brand="Generic" data-category="Electronics/Accessories/Gadgets" data-dimension23="161548" data-dimension26="2" data-dimension27="4" data-dimension28="0" data-dimension37="0" data-dimension43="" data-dimension44="0" data-id="GE779EL11V8YENAFAMZ" data-name="Shirt Button Camera Pinhole Mini Dv Dvr Voice Video Recorder" data-price="21.85" data-simplesku="GE779EL11V8YENAFAMZ-61594144" data-sku="GE779EL11V8YENAFAMZ" data-svar="GE779EL11V8YENAFAMZ-61594144" data-track-onsubmit="addToCart" data-variant="" data-xhr="" method="post"><button class="add btn _prim -pea _md" data-submit="" name="action" type="button" value="in">Add To Cart</button><input name="csrfToken" type="hidden" value="8803343367b5e6963475577f45310df4"/></form></footer></article>,
#  <article class="prd _fb col c-prd"><a class="core" data-brand="Generic" data-category="Electronics/Accessories/Gadgets" data-dimension23="260960" data-dimension26="" data-dimension27="" data-dimension28="0" data-dimension37="0" data-dimension43="" data-dimension44="0" data-id="GE779EL1L9JY3NAFAMZ" data-list="" data-name="Fixed GSM Wireless Terminal- Gateway GSM850/1900/ 900/1800MHz Quad Band" data-position="19" data-price="39.31" data-track-onclick="eecProduct" data-track-onview="eecProduct" href="/generic-fixed-gsm-wireless-terminal-gateway-gsm8501900-9001800mhz-quad-band-76838169.html"><div class="img-c"><img alt="" class="img" data-lazy="" data-src="https://ng.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/96/183867/1.jpg?7111" height="208" src="..." width="208"/></div><div class="info"><h3 class="name">Fixed GSM Wireless Terminal- Gateway GSM850/1900/ 900/1800MHz Quad Band</h3><div class="prc">₦ 17,990</div><div class="s-prc-w"><div class="old">₦ 25,000</div><div class="tag _dsct _sm">28%</div></div></div></a><footer class="ft"><div class="-df -i-ctr -pr -j-bet" data-add-cart="" data-sku="GE779EL1L9JY3NAFAMZ" data-svar="GE779EL1L9JY3NAFAMZ-105808631" data-xhr=""><button class="add btn _prim -pea _md" data-trigpopup="" type="button">Add To Cart</button></div></footer></article>,
#  <article class="prd _fb col c-prd"><a class="core" data-brand="ZTE" data-category="Electronics/Accessories/Gadgets" data-dimension23="303145" data-dimension26="" data-dimension27="" data-dimension28="0" data-dimension37="0" data-dimension43="" data-dimension44="0" data-id="ZT786EA01GXBCNAFAMZ" data-list="" data-name="Universal Mobile 3G/4G Wifi / Mifi" data-position="20" data-price="67.74" data-track-onclick="eecProduct" data-track-onview="eecProduct" href="/zte-universal-mobile-3g4g-wifi-mifi-88296420.html"><div class="img-c"><img alt="" class="img" data-lazy="" data-src="https://ng.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/02/469288/1.jpg?5874" height="208" src="..." width="208"/></div><div class="info"><h3 class="name">ZTE Universal Mobile 3G/4G Wifi / Mifi</h3><div class="prc">₦ 31,000</div></div></a><footer class="ft"><div class="-df -i-ctr -pr -j-bet" data-add-cart="" data-sku="ZT786EA01GXBCNAFAMZ" data-svar="ZT786EA01GXBCNAFAMZ-119728855" data-xhr=""><button class="add btn _prim -pea _md" data-trigpopup="" type="button">Add To Cart</button></div></footer></article>,
#  <article class="prd _fb col c-prd"><a class="core" data-brand="Generic" data-category="Electronics/Accessories/Gadgets" data-dimension23="119175" data-dimension26="" data-dimension27="" data-dimension28="0" data-dimension37="1" data-dimension43="" data-dimension44="0" data-id="GE779EA034KOINAFAMZ" data-list="" data-name="Digital LCD Electronic Plug-in Programmable Timer 12/24 Hour Switch Socket With Clock Summer Time Random Function 230V 50Hz" data-position="21" data-price="17.04" data-track-onclick="eecProduct" data-track-onview="eecProduct" href="/generic-digital-lcd-electronic-plug-in-programmable-timer-1224-hour-switch-socket-with-clock-summer-time-random-function-230v-50hz-47225250.html"><div class="img-c"><img alt="" class="img" data-lazy="" data-src="https://ng.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/05/252274/1.jpg?6373" height="208" src="..." width="208"/></div><div class="info"><div class="tag _glb _sm">Shipped from abroad</div><h3 class="name">Digital LCD Electronic Plug-in Programmable Timer 12/24 Hour Switch Socket With Clock Summer Time Random Function 230V 50Hz</h3><div class="prc">₦ 7,796</div><div class="s-prc-w"><div class="old">₦ 13,633</div><div class="tag _dsct _sm">43%</div></div></div></a><footer class="ft"><form action="/cart/products/GE779EA034KOINAFAMZ-67106463/quantity/" class="-df -i-ctr -pr -j-bet" data-add-cart="" data-brand="Generic" data-category="Electronics/Accessories/Gadgets" data-dimension23="119175" data-dimension26="" data-dimension27="" data-dimension28="0" data-dimension37="1" data-dimension43="" data-dimension44="0" data-id="GE779EA034KOINAFAMZ" data-name="Digital LCD Electronic Plug-in Programmable Timer 12/24 Hour Switch Socket With Clock Summer Time Random Function 230V 50Hz" data-price="17.04" data-simplesku="GE779EA034KOINAFAMZ-67106463" data-sku="GE779EA034KOINAFAMZ" data-svar="GE779EA034KOINAFAMZ-67106463" data-track-onsubmit="addToCart" data-variant="" data-xhr="" method="post"><button class="add btn _prim -pea _md" data-submit="" name="action" type="button" value="in">Add To Cart</button><input name="csrfToken" type="hidden" value="8803343367b5e6963475577f45310df4"/></form></footer></article>,
#  <article class="prd _fb col c-prd"><a class="core" data-brand="Generic" data-category="Electronics/Accessories/Gadgets" data-dimension23="286095" data-dimension26="" data-dimension27="" data-dimension28="0" data-dimension37="0" data-dimension43="" data-dimension44="0" data-id="GE779EL0FUA8KNAFAMZ" data-list="" data-name="Supper Gun Spraying Money Machine" data-position="22" data-price="21.85" data-track-onclick="eecProduct" data-track-onview="eecProduct" href="/generic-supper-gun-spraying-money-machine-88170662.html"><div class="img-c"><img alt="" class="img" data-lazy="" data-src="https://ng.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/26/607188/1.jpg?7245" height="208" src="..." width="208"/></div><div class="info"><h3 class="name">Supper Gun Spraying Money Machine</h3><div class="prc">₦ 10,000</div><div class="s-prc-w"><div class="old">₦ 20,000</div><div class="tag _dsct _sm">50%</div></div></div></a><footer class="ft"><form action="/cart/products/GE779EL0FUA8KNAFAMZ-119592519/quantity/" class="-df -i-ctr -pr -j-bet" data-add-cart="" data-brand="Generic" data-category="Electronics/Accessories/Gadgets" data-dimension23="286095" data-dimension26="" data-dimension27="" data-dimension28="0" data-dimension37="0" data-dimension43="" data-dimension44="0" data-id="GE779EL0FUA8KNAFAMZ" data-name="Supper Gun Spraying Money Machine" data-price="21.85" data-simplesku="GE779EL0FUA8KNAFAMZ-119592519" data-sku="GE779EL0FUA8KNAFAMZ" data-svar="GE779EL0FUA8KNAFAMZ-119592519" data-track-onsubmit="addToCart" data-variant="" data-xhr="" method="post"><button class="add btn _prim -pea _md" data-submit="" name="action" type="button" value="in">Add To Cart</button><input name="csrfToken" type="hidden" value="8803343367b5e6963475577f45310df4"/></form></footer></article>,
#  <article class="prd _fb col c-prd"><a class="core" data-brand="Garmin" data-category="Electronics/Accessories/Gadgets" data-dimension23="92116" data-dimension26="3" data-dimension27="4.7" data-dimension28="0" data-dimension37="0" data-dimension43="" data-dimension44="0" data-id="GE673EA0XB5ESNAFAMZ" data-list="" data-name="ETrex 10 Worldwide Handheld GPS Navigator" data-position="23" data-price="207.59" data-track-onclick="eecProduct" data-track-onview="eecProduct" href="/garmin-etrex-10-worldwide-handheld-gps-navigator-65574955.html"><div class="img-c"><img alt="" class="img" data-lazy="" data-src="https://ng.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/55/947556/1.jpg?1849" height="208" src="..." width="208"/></div><div class="info"><h3 class="name">Garmin ETrex 10 Worldwide Handheld GPS Navigator</h3><div class="prc">₦ 95,000</div><div class="rev"><div class="stars _s">4.7 out of 5<div class="in" style="width:94%"></div></div>(3)</div></div></a><footer class="ft"><form action="/cart/products/GE673EA0XB5ESNAFAMZ-91884636/quantity/" class="-df -i-ctr -pr -j-bet" data-add-cart="" data-brand="Garmin" data-category="Electronics/Accessories/Gadgets" data-dimension23="92116" data-dimension26="3" data-dimension27="4.7" data-dimension28="0" data-dimension37="0" data-dimension43="" data-dimension44="0" data-id="GE673EA0XB5ESNAFAMZ" data-name="ETrex 10 Worldwide Handheld GPS Navigator" data-price="207.59" data-simplesku="GE673EA0XB5ESNAFAMZ-91884636" data-sku="GE673EA0XB5ESNAFAMZ" data-svar="GE673EA0XB5ESNAFAMZ-91884636" data-track-onsubmit="addToCart" data-variant="" data-xhr="" method="post"><button class="add btn _prim -pea _md" data-submit="" name="action" type="button" value="in">Add To Cart</button><input name="csrfToken" type="hidden" value="8803343367b5e6963475577f45310df4"/></form></footer></article>,
#  <article class="prd _fb col c-prd"><a class="core" data-brand="Baofeng" data-category="Electronics/Accessories/Gadgets" data-dimension23="153021" data-dimension26="1" data-dimension27="3" data-dimension28="0" data-dimension37="0" data-dimension43="" data-dimension44="0" data-id="BA175EL0GYWDONAFAMZ" data-list="" data-name="POLICE Walkie Talkie Radio BF-888S - 10 Pcs" data-position="24" data-price="131.11" data-track-onclick="eecProduct" data-track-onview="eecProduct" href="/police-walkie-talkie-radio-bf-888s-10-pcs-baofeng-mpg1205460.html"><div class="img-c"><img alt="" class="img" data-lazy="" data-src="https://ng.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/28/502124/1.jpg?6899" height="208" src="..." width="208"/></div><div class="info"><h3 class="name">Baofeng POLICE Walkie Talkie Radio BF-888S - 10 Pcs</h3><div class="prc">₦ 60,000</div><div class="s-prc-w"><div class="old">₦ 65,000</div><div class="tag _dsct _sm">8%</div></div><p class="mpg" data-prc="₦ 60,000" data-tot="3">offers from</p><div class="rev"><div class="stars _s">3 out of 5<div class="in" style="width:60%"></div></div>(1)</div></div></a><footer class="ft"><form action="/cart/products/BA175EL0GYWDONAFAMZ-58645243/quantity/" class="-df -i-ctr -pr -j-bet" data-add-cart="" data-brand="Baofeng" data-category="Electronics/Accessories/Gadgets" data-dimension23="153021" data-dimension26="1" data-dimension27="3" data-dimension28="0" data-dimension37="0" data-dimension43="" data-dimension44="0" data-id="BA175EL0GYWDONAFAMZ" data-name="POLICE Walkie Talkie Radio BF-888S - 10 Pcs" data-price="131.11" data-simplesku="BA175EL0GYWDONAFAMZ-58645243" data-sku="BA175EL0GYWDONAFAMZ" data-svar="BA175EL0GYWDONAFAMZ-58645243" data-track-onsubmit="addToCart" data-variant="" data-xhr="" method="post"><button class="add btn _prim -pea _md" data-submit="" name="action" type="button" value="in">Add To Cart</button><input name="csrfToken" type="hidden" value="8803343367b5e6963475577f45310df4"/></form></footer></article>,
#  <article class="prd _fb col c-prd"><a class="core" data-brand="Generic" data-category="Electronics/Accessories/Gadgets" data-dimension23="63663" data-dimension26="3" data-dimension27="5" data-dimension28="0" data-dimension37="0" data-dimension43="" data-dimension44="0" data-id="UN970EL19F3C1NAFAMZ" data-list="" data-name="PANAROMA WIFI CCTV CAMERA" data-position="25" data-price="26.22" data-track-onclick="eecProduct" data-track-onview="eecProduct" href="/generic-panaroma-wifi-cctv-camera-18868267.html"><div class="img-c"><img alt="" class="img" data-lazy="" data-src="https://ng.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/76/286881/1.jpg?0811" height="208" src="..." width="208"/></div><div class="info"><h3 class="name">PANAROMA WIFI CCTV CAMERA</h3><div class="prc">₦ 12,000</div><div class="s-prc-w"><div class="old">₦ 30,000</div><div class="tag _dsct _sm">60%</div></div><div class="rev"><div class="stars _s">5 out of 5<div class="in" style="width:100%"></div></div>(3)</div></div></a><footer class="ft"><div class="-df -i-ctr -pr -j-bet" data-add-cart="" data-sku="UN970EL19F3C1NAFAMZ" data-svar="UN970EL19F3C1NAFAMZ-24720522" data-xhr=""><button class="add btn _prim -pea _md" data-trigpopup="" type="button">Add To Cart</button></div></footer></article>,
#  <article class="prd _fb col c-prd"><a class="core" data-brand="Generic" data-category="Electronics/Accessories/Gadgets" data-dimension23="105683" data-dimension26="3" data-dimension27="4.3" data-dimension28="0" data-dimension37="0" data-dimension43="" data-dimension44="0" data-id="GE779EL01E9LXNAFAMZ" data-list="" data-name="High Vision Spyglass Camera Glasses Hidden Camera HD." data-position="26" data-price="49.17" data-track-onclick="eecProduct" data-track-onview="eecProduct" href="/generic-high-vision-spyglass-camera-glasses-hidden-camera-hd.-35254320.html"><div class="img-c"><img alt="" class="img" data-lazy="" data-src="https://ng.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/02/345253/1.jpg?8513" height="208" src="..." width="208"/></div><div class="info"><h3 class="name">High Vision Spyglass Camera Glasses Hidden Camera HD.</h3><div class="prc">₦ 22,500</div><div class="s-prc-w"><div class="old">₦ 25,000</div><div class="tag _dsct _sm">10%</div></div><div class="rev"><div class="stars _s">4.3 out of 5<div class="in" style="width:86%"></div></div>(3)</div></div></a><footer class="ft"><form action="/cart/products/GE779EL01E9LXNAFAMZ-47384894/quantity/" class="-df -i-ctr -pr -j-bet" data-add-cart="" data-brand="Generic" data-category="Electronics/Accessories/Gadgets" data-dimension23="105683" data-dimension26="3" data-dimension27="4.3" data-dimension28="0" data-dimension37="0" data-dimension43="" data-dimension44="0" data-id="GE779EL01E9LXNAFAMZ" data-name="High Vision Spyglass Camera Glasses Hidden Camera HD." data-price="49.17" data-simplesku="GE779EL01E9LXNAFAMZ-47384894" data-sku="GE779EL01E9LXNAFAMZ" data-svar="GE779EL01E9LXNAFAMZ-47384894" data-track-onsubmit="addToCart" data-variant="" data-xhr="" method="post"><button class="add btn _prim -pea _md" data-submit="" name="action" type="button" value="in">Add To Cart</button><input name="csrfToken" type="hidden" value="8803343367b5e6963475577f45310df4"/></form></footer></article>,
#  <article class="prd _fb col c-prd"><a class="core" data-brand="Generic" data-category="Electronics/Accessories/Gadgets" data-dimension23="136665" data-dimension26="" data-dimension27="" data-dimension28="0" data-dimension37="0" data-dimension43="" data-dimension44="0" data-id="GE779EL020Q4LNAFAMZ" data-list="" data-name="Mobile Eyewear Recorder/Camera- Black" data-position="27" data-price="25.13" data-track-onclick="eecProduct" data-track-onview="eecProduct" href="/mobile-eyewear-recordercamera-black-generic-mpg1200974.html"><div class="img-c"><img alt="" class="img" data-lazy="" data-src="https://ng.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/03/393093/1.jpg?4764" height="208" src="..." width="208"/></div><div class="info"><h3 class="name">Mobile Eyewear Recorder/Camera- Black</h3><div class="prc">₦ 11,499</div><div class="s-prc-w"><div class="old">₦ 12,400</div><div class="tag _dsct _sm">7%</div></div></div></a><footer class="ft"><form action="/cart/products/GE779EL020Q4LNAFAMZ-52773471/quantity/" class="-df -i-ctr -pr -j-bet" data-add-cart="" data-brand="Generic" data-category="Electronics/Accessories/Gadgets" data-dimension23="136665" data-dimension26="" data-dimension27="" data-dimension28="0" data-dimension37="0" data-dimension43="" data-dimension44="0" data-id="GE779EL020Q4LNAFAMZ" data-name="Mobile Eyewear Recorder/Camera- Black" data-price="25.13" data-simplesku="GE779EL020Q4LNAFAMZ-52773471" data-sku="GE779EL020Q4LNAFAMZ" data-svar="GE779EL020Q4LNAFAMZ-52773471" data-track-onsubmit="addToCart" data-variant="" data-xhr="" method="post"><button class="add btn _prim -pea _md" data-submit="" name="action" type="button" value="in">Add To Cart</button><input name="csrfToken" type="hidden" value="8803343367b5e6963475577f45310df4"/></form></footer></article>,
# ...
#  <article class="prd _fb col c-prd"><a class="core" data-brand="Generic" data-category="Electronics/Accessories/Gadgets" data-dimension23="136665" data-dimension26="" data-dimension27="" data-dimension28="0" data-dimension37="0" data-dimension43="" data-dimension44="0" data-id="GE779EL1EBF07NAFAMZ" data-list="" data-name="Hidden DV DVR HD Suit Button Camera 8GB 16GB 32GB Micro Card" data-position="33" data-price="21.85" data-track-onclick="eecProduct" data-track-onview="eecProduct" href="/generic-hidden-dv-dvr-hd-suit-button-camera-8gb-16gb-32gb-micro-card-36431548.html"><div class="img-c"><img alt="" class="img" data-lazy="" data-src="https://ng.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/84/513463/1.jpg?1782" height="208" src="..." width="208"/></div><div class="info"><h3 class="name">Hidden DV DVR HD Suit Button Camera 8GB 16GB 32GB Micro Card</h3><div class="prc">₦ 9,999</div><div class="s-prc-w"><div class="old">₦ 19,500</div><div class="tag _dsct _sm">49%</div></div></div></a><footer class="ft"><form action="/cart/products/GE779EL1EBF07NAFAMZ-49202808/quantity/" class="-df -i-ctr -pr -j-bet" data-add-cart="" data-brand="Generic" data-category="Electronics/Accessories/Gadgets" data-dimension23="136665" data-dimension26="" data-dimension27="" data-dimension28="0" data-dimension37="0" data-dimension43="" data-dimension44="0" data-id="GE779EL1EBF07NAFAMZ" data-name="Hidden DV DVR HD Suit Button Camera 8GB 16GB 32GB Micro Card" data-price="21.85" data-simplesku="GE779EL1EBF07NAFAMZ-49202808" data-sku="GE779EL1EBF07NAFAMZ" data-svar="GE779EL1EBF07NAFAMZ-49202808" data-track-onsubmit="addToCart" data-variant="" data-xhr="" method="post"><button class="add btn _prim -pea _md" data-submit="" name="action" type="button" value="in">Add To Cart</button><input name="csrfToken" type="hidden" value="8803343367b5e6963475577f45310df4"/></form></footer></article>,
#  <article class="prd _fb col c-prd"><a class="core" data-brand="Generic" data-category="Electronics/Accessories/Gadgets" data-dimension23="262169" data-dimension26="1" data-dimension27="4" data-dimension28="0" data-dimension37="0" data-dimension43="" data-dimension44="0" data-id="GE779EA0FRRWLNAFAMZ" data-list="" data-name="14-55 Inches LED/LCD TV Wall Hanger/Bracket + TV Guard." data-position="34" data-price="8.74" data-track-onclick="eecProduct" data-track-onview="eecProduct" href="/generic-14-55-inches-ledlcd-tv-wall-hangerbracket-tv-guard.-71109462.html"><div class="img-c"><img alt="" class="img" data-lazy="" data-src="https://ng.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/26/490117/1.jpg?2728" height="208" src="..." width="208"/></div><div class="info"><h3 class="name">14-55 Inches LED/LCD TV Wall Hanger/Bracket + TV Guard.</h3><div class="prc">₦ 4,000 - ₦ 4,500</div><div class="s-prc-w"><div class="old">₦ 7,000</div><div class="tag _dsct _sm">43%</div></div><div class="rev"><div class="stars _s">4 out of 5<div class="in" style="width:80%"></div></div>(1)</div></div></a><footer class="ft"><div class="-df -i-ctr -pr -j-bet" data-add-cart="" data-sku="GE779EA0FRRWLNAFAMZ" data-xhr=""><button class="add btn _prim -pea _md" data-trigpopup="" type="button">Add To Cart</button></div></footer></article>,
#  <article class="prd _fb col c-prd"><a class="core" data-brand="Generic" data-category="Electronics/Accessories/Gadgets" data-dimension23="288709" data-dimension26="" data-dimension27="" data-dimension28="0" data-dimension37="0" data-dimension43="DOW_21" data-dimension44="0" data-id="GE779EL0MYLNINAFAMZ" data-list="" data-name="High Vision Spyglass Camera Glasses Hidden Camera HD." data-position="35" data-price="53.54" data-track-onclick="eecProduct" data-track-onview="eecProduct" href="/generic-high-vision-spyglass-camera-glasses-hidden-camera-hd.-81956583.html"><div class="img-c"><img alt="" class="img" data-lazy="" data-src="https://ng.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/38/565918/1.jpg?1255" height="208" src="..." width="208"/></div><div class="info"><h3 class="name">High Vision Spyglass Camera Glasses Hidden Camera HD.</h3><div class="prc">₦ 24,500</div><div class="s-prc-w"><div class="old">₦ 27,000</div><div class="tag _dsct _sm">9%</div></div></div></a><footer class="ft"><form action="/cart/products/GE779EL0MYLNINAFAMZ-112171929/quantity/" class="-df -i-ctr -pr -j-bet" data-add-cart="" data-brand="Generic" data-category="Electronics/Accessories/Gadgets" data-dimension23="288709" data-dimension26="" data-dimension27="" data-dimension28="0" data-dimension37="0" data-dimension43="DOW_21" data-dimension44="0" data-id="GE779EL0MYLNINAFAMZ" data-name="High Vision Spyglass Camera Glasses Hidden Camera HD." data-price="53.54" data-simplesku="GE779EL0MYLNINAFAMZ-112171929" data-sku="GE779EL0MYLNINAFAMZ" data-svar="GE779EL0MYLNINAFAMZ-112171929" data-track-onsubmit="addToCart" data-variant="" data-xhr="" method="post"><button class="add btn _prim -pea _md" data-submit="" name="action" type="button" value="in">Add To Cart</button><input name="csrfToken" type="hidden" value="8803343367b5e6963475577f45310df4"/></form></footer></article>,
#  <article class="prd _fb col c-prd"><a class="core" data-brand="Generic" data-category="Electronics/Accessories/Gadgets" data-dimension23="108390" data-dimension26="" data-dimension27="" data-dimension28="0" data-dimension37="0" data-dimension43="" data-dimension44="0" data-id="GE779EL02JPE3NAFAMZ" data-list="" data-name="Electric Air Pump For Airbed" data-position="36" data-price="26.22" data-track-onclick="eecProduct" data-track-onview="eecProduct" href="/generic-electric-air-pump-for-airbed-30687240.html"><div class="img-c"><img alt="" class="img" data-lazy="" data-src="https://ng.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/04/278603/1.jpg?3039" height="208" src="..." width="208"/></div><div class="info"><h3 class="name">Electric Air Pump For Airbed</h3><div class="prc">₦ 11,998</div></div></a><footer class="ft"><form action="/cart/products/GE779EL02JPE3NAFAMZ-40383387/quantity/" class="-df -i-ctr -pr -j-bet" data-add-cart="" data-brand="Generic" data-category="Electronics/Accessories/Gadgets" data-dimension23="108390" data-dimension26="" data-dimension27="" data-dimension28="0" data-dimension37="0" data-dimension43="" data-dimension44="0" data-id="GE779EL02JPE3NAFAMZ" data-name="Electric Air Pump For Airbed" data-price="26.22" data-simplesku="GE779EL02JPE3NAFAMZ-40383387" data-sku="GE779EL02JPE3NAFAMZ" data-svar="GE779EL02JPE3NAFAMZ-40383387" data-track-onsubmit="addToCart" data-variant="" data-xhr="" method="post"><button class="add btn _prim -pea _md" data-submit="" name="action" type="button" value="in">Add To Cart</button><input name="csrfToken" type="hidden" value="8803343367b5e6963475577f45310df4"/></form></footer></article>,
#  <article class="prd _fb col c-prd"><a class="core" data-brand="Daniu" data-category="Electronics/Accessories/Gadgets" data-dimension23="75731" data-dimension26="" data-dimension27="" data-dimension28="0" data-dimension37="1" data-dimension43="" data-dimension44="0" data-id="DA297EL00XAFENAFAMZ" data-list="" data-name="110V 300W DIY Electric Heat Shrink Gun Power Tool Hot Air Temperature Gun With Supporting Seat" data-position="37" data-price="17.31" data-track-onclick="eecProduct" data-track-onview="eecProduct" href="/daniu-110v-300w-diy-electric-heat-shrink-gun-power-tool-hot-air-temperature-gun-with-supporting-seat-26135510.html"><div class="img-c"><img alt="" class="img" data-lazy="" data-src="https://ng.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/01/553162/1.jpg?2032" height="208" src="..." width="208"/></div><div class="info"><div class="tag _glb _sm">Shipped from abroad</div><h3 class="name">Daniu 110V 300W DIY Electric Heat Shrink Gun Power Tool Hot Air Temperature Gun With Supporting Seat</h3><div class="prc">₦ 7,920</div><div class="s-prc-w"><div class="old">₦ 15,840</div><div class="tag _dsct _sm">50%</div></div></div></a><footer class="ft"><form action="/cart/products/DA297EL00XAFENAFAMZ-34885751/quantity/" class="-df -i-ctr -pr -j-bet" data-add-cart="" data-brand="Daniu" data-category="Electronics/Accessories/Gadgets" data-dimension23="75731" data-dimension26="" data-dimension27="" data-dimension28="0" data-dimension37="1" data-dimension43="" data-dimension44="0" data-id="DA297EL00XAFENAFAMZ" data-name="110V 300W DIY Electric Heat Shrink Gun Power Tool Hot Air Temperature Gun With Supporting Seat" data-price="17.31" data-simplesku="DA297EL00XAFENAFAMZ-34885751" data-sku="DA297EL00XAFENAFAMZ" data-svar="DA297EL00XAFENAFAMZ-34885751" data-track-onsubmit="addToCart" data-variant="" data-xhr="" method="post"><button class="add btn _prim -pea _md" data-submit="" name="action" type="button" value="in">Add To Cart</button><input name="csrfToken" type="hidden" value="8803343367b5e6963475577f45310df4"/></form></footer></article>,
#  <article class="prd _fb col c-prd"><a class="core" data-brand="Generic" data-category="Electronics/Accessories/Gadgets" data-dimension23="136567" data-dimension26="4" data-dimension27="3.3" data-dimension28="0" data-dimension37="0" data-dimension43="" data-dimension44="0" data-id="GE779EL0BJ747NAFAMZ" data-list="" data-name="Hidden DV DVR HD Suit Button Camera 8GB 16GB 32GB Micro Card" data-position="38" data-price="20.76" data-track-onclick="eecProduct" data-track-onview="eecProduct" href="/hidden-dv-dvr-hd-suit-button-camera-8gb-16gb-32gb-micro-card-generic-mpg342282.html"><div class="img-c"><img alt="" class="img" data-lazy="" data-src="https://ng.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/19/371463/1.jpg?3006" height="208" src="..." width="208"/></div><div class="info"><h3 class="name">Hidden DV DVR HD Suit Button Camera 8GB 16GB 32GB Micro Card</h3><div class="prc">₦ 9,500</div><div class="s-prc-w"><div class="old">₦ 9,999</div><div class="tag _dsct _sm">5%</div></div><p class="mpg" data-prc="₦ 9,500" data-tot="2">offers from</p><div class="rev"><div class="stars _s">3.3 out of 5<div class="in" style="width:66%"></div></div>(4)</div></div></a><footer class="ft"><form action="/cart/products/GE779EL0BJ747NAFAMZ-49187171/quantity/" class="-df -i-ctr -pr -j-bet" data-add-cart="" data-brand="Generic" data-category="Electronics/Accessories/Gadgets" data-dimension23="136567" data-dimension26="4" data-dimension27="3.3" data-dimension28="0" data-dimension37="0" data-dimension43="" data-dimension44="0" data-id="GE779EL0BJ747NAFAMZ" data-name="Hidden DV DVR HD Suit Button Camera 8GB 16GB 32GB Micro Card" data-price="20.76" data-simplesku="GE779EL0BJ747NAFAMZ-49187171" data-sku="GE779EL0BJ747NAFAMZ" data-svar="GE779EL0BJ747NAFAMZ-49187171" data-track-onsubmit="addToCart" data-variant="" data-xhr="" method="post"><button class="add btn _prim -pea _md" data-submit="" name="action" type="button" value="in">Add To Cart</button><input name="csrfToken" type="hidden" value="8803343367b5e6963475577f45310df4"/></form></footer></article>,
#  <article class="prd _fb col c-prd"><a class="core" data-brand="Gts" data-category="Electronics/Accessories/Gadgets" data-dimension23="117484" data-dimension26="9" data-dimension27="4.6" data-dimension28="0" data-dimension37="0" data-dimension43="" data-dimension44="0" data-id="GT907EL0MCYL0NAFAMZ" data-list="" data-name="G T S Professional Cliper" data-position="39" data-price="19.56" data-track-onclick="eecProduct" data-track-onview="eecProduct" href="/g-t-s-professional-cliper-gts-mpg1223900.html"><div class="img-c"><img alt="" class="img" data-lazy="" data-src="https://ng.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/37/556244/1.jpg?9213" height="208" src="..." width="208"/></div><div class="info"><h3 class="name">Gts G T S Professional Cliper</h3><div class="prc">₦ 8,950</div><div class="rev"><div class="stars _s">4.6 out of 5<div class="in" style="width:91.99999999999999%"></div></div>(9)</div></div></a><footer class="ft"><form action="/cart/products/GT907EL0MCYL0NAFAMZ-62431339/quantity/" class="-df -i-ctr -pr -j-bet" data-add-cart="" data-brand="Gts" data-category="Electronics/Accessories/Gadgets" data-dimension23="117484" data-dimension26="9" data-dimension27="4.6" data-dimension28="0" data-dimension37="0" data-dimension43="" data-dimension44="0" data-id="GT907EL0MCYL0NAFAMZ" data-name="G T S Professional Cliper" data-price="19.56" data-simplesku="GT907EL0MCYL0NAFAMZ-62431339" data-sku="GT907EL0MCYL0NAFAMZ" data-svar="GT907EL0MCYL0NAFAMZ-62431339" data-track-onsubmit="addToCart" data-variant="" data-xhr="" method="post"><button class="add btn _prim -pea _md" data-submit="" name="action" type="button" value="in">Add To Cart</button><input name="csrfToken" type="hidden" value="8803343367b5e6963475577f45310df4"/></form></footer></article>,
#  <article class="prd _fb col c-prd"><a class="core" data-brand="Generic" data-category="Electronics/Accessories/Gadgets" data-dimension23="279900" data-dimension26="" data-dimension27="" data-dimension28="0" data-dimension37="0" data-dimension43="" data-dimension44="0" data-id="GE779EL0LIIY1NAFAMZ" data-list="" data-name="Commscope Cat6 Systimax Gigaspeed Pure Copper Cable" data-position="40" data-price="131.11" data-track-onclick="eecProduct" data-track-onview="eecProduct" href="/generic-commscope-cat6-systimax-gigaspeed-pure-copper-cable-79263163.html"><div class="img-c"><img alt="" class="img" data-lazy="" data-src="https://ng.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/36/136297/1.jpg?7083" height="208" src="..." width="208"/></div><div class="info"><h3 class="name">Commscope Cat6 Systimax Gigaspeed Pure Copper Cable</h3><div class="prc">₦ 60,000</div><div class="s-prc-w"><div class="old">₦ 70,000</div><div class="tag _dsct _sm">14%</div></div></div></a><footer class="ft"><form action="/cart/products/GE779EL0LIIY1NAFAMZ-108803919/quantity/" class="-df -i-ctr -pr -j-bet" data-add-cart="" data-brand="Generic" data-category="Electronics/Accessories/Gadgets" data-dimension23="279900" data-dimension26="" data-dimension27="" data-dimension28="0" data-dimension37="0" data-dimension43="" data-dimension44="0" data-id="GE779EL0LIIY1NAFAMZ" data-name="Commscope Cat6 Systimax Gigaspeed Pure Copper Cable" data-price="131.11" data-simplesku="GE779EL0LIIY1NAFAMZ-108803919" data-sku="GE779EL0LIIY1NAFAMZ" data-svar="GE779EL0LIIY1NAFAMZ-108803919" data-track-onsubmit="addToCart" data-variant="" data-xhr="" method="post"><button class="add btn _prim -pea _md" data-submit="" name="action" type="button" value="in">Add To Cart</button><input name="csrfToken" type="hidden" value="8803343367b5e6963475577f45310df4"/></form></footer></article>]

# %% [markdown]
# ## Target Necessary Data

# %%
# Product name
# Product price
# Product old price
# Product Rating
# Product Discount
# Product URL

# %% [markdown]
# ## Product Name

# %%
# For the name we go back to the name and inspect the tag

me[3].find('h3',{'class':'name'}).get_text().strip()
# Out:
# 'ZTE Universal Mobile 3G/4G Wifi / Mifi'

# %% [markdown]
# ## Product Price

# %%
# we go back to the page and inspect the product price

# %%
me[0].find('div',{'class':'prc'}).get_text().strip()
# Out:
# '₦ 6,500'

# %% [markdown]
# ## Product URL

# %%
me[0].find('a').get('href').strip()
# Out:
# '/generic-security-metal-detector-garrett-82285696.html'

# %% [markdown]
# ## Product Rating

# %%
me[0].find('div',{'class':'rev'}).get_text()
# Out:
# '4.8 out of 5(4)'

# %% [markdown]
# ## Product Old Price

# %%
me[0].find('div',{'class': 'old'}).get_text().strip()
# Out:
# '₦ 9,000'

# %% [markdown]
# ## Product Discount

# %%
me[0].find('div',{'class': 'tag _dsct _sm'}).get_text().strip()
# Out:
# '28%'

# %% [markdown]
# ## Picture Image

# %%
# Trying to scrape and print an image from the web
# Scraped the image url

Zara = me[0].find('img').get('data-src')

print(Zara)
# Out:
# https://ng.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/69/658228/1.jpg?7708

# %%
# To print the image fromm the web

import matplotlib.pyplot as plt
import matplotlib.image as mpim

# %% [markdown]
# ## Putting everything together

# %%
product_name = []
product_oldprice =[]
product_price = []
product_discount =[]
product_rating = []
product_url = []

for result in me:
    '''Product name'''
    try:
        product_name.append(result.find('h3',{'class':'name'})).get_text().strip()
    except:
            product_name.append('n/a')
            
    # product price 
    try:
        product_price.append(result.find('div',{'class':'prc'})).get_text().strip()
    except:
            product_price.append('n/a')
            
    # Product old price
    try:
        product_oldprice.append(result.find('div',{'class': 'old'})).get_text().strip()
    except:
            product_oldprice.append('n/a')
            
    # Product Discount
    try:
        product_discount.append(result.find('div',{'class': 'tag _dsct _sm'})).get_text().strip()
    except:
            product_discount.append('n/a')
        
    # Product rating
    try:
        product_rating.append(result.find('div',{'class':'rev'})).get_text().strip()
    except:
            product_rating.append('n/a')
            
    # Product Url
    try:
        product_url.append(result.find('a').get('href')).strip()
    except:
            product_url.append('n/a')

# %% [markdown]
# ## Pandas Framework

# %%
pandas_overview = pd.DataFrame ({'Product name': product_name,
                                'Old price': product_oldprice,
                                'New price': product_price,
                                'Discount': product_discount,
                                'Rating': product_rating,
                                'Url':product_url})

# %%
pandas_overview
# Out:
#                                          Product name   Old price   New price  \
# 0                   [Security Metal Detector Garrett]   [₦ 9,000]   [₦ 6,500]
# 1                                                 n/a         n/a         n/a
# 2            [ZTE Universal Mobile 3G/4G Wifi / Mifi]  [₦ 32,000]  [₦ 25,790]
# 3                                                 n/a         n/a         n/a
# 4                   [TV STREAMING DEVICE CHROME CAST]        None   [₦ 8,500]
# ..                                                ...         ...         ...
# 75                                                n/a         n/a         n/a
# 76                    [Gts G T S Professional Cliper]        None   [₦ 8,950]
# 77                                                n/a         n/a         n/a
# 78  [Commscope Cat6 Systimax Gigaspeed Pure Copper...  [₦ 70,000]  [₦ 60,000]
# 79                                                n/a         n/a         n/a
#
#    Discount                     Rating  \
# 0     [28%]  [[4.8 out of 5, []], (4)]
# 1       n/a                        n/a
# 2     [19%]                       None
# 3       n/a                        n/a
# 4      None                       None
# ..      ...                        ...
# 75      n/a                        n/a
# 76     None  [[4.6 out of 5, []], (9)]
# 77      n/a                        n/a
# 78    [14%]                       None
# 79      n/a                        n/a
#
#                                                   Url
# 0   /generic-security-metal-detector-garrett-82285...
# 1                                                 n/a
# 2   /zte-universal-mobile-3g4g-wifi-mifi-65308334....
# 3                                                 n/a
# 4   /generic-tv-streaming-device-chrome-cast-98909...
# ..                                                ...
# 75                                                n/a
# 76     /g-t-s-professional-cliper-gts-mpg1223900.html
# 77                                                n/a
# 78  /generic-commscope-cat6-systimax-gigaspeed-pur...
# 79                                                n/a
#
# [80 rows x 6 columns]

# %% [markdown]
# ## Export to Excel

# %%
pandas_overview.to_excel('Jumi Products.xlsx')

# %% [markdown]
# ## Multiple Pages

# %%
product_name = []
product_oldprice =[]
product_price = []
product_discount =[]
product_rating = []
product_url = []

for i in range(1,100):
    websiite= website ='https://www.jumia.com.ng/electronics-accessories/'
    
    #request
    me = requests.get(website)
    
    # Soup
    soup = BeautifulSoup(me.content, 'html.parser')
    
    # me
   # me = soup.find_all ('article',{'class': 'prd _fb col c-prd'})
    
    me = soup.find_all ('div',{'class': '-paxs row _no-g _4cl-3cm-shs'})
    
   
    # Loop through results
    for result in me:
        '''Product name'''
    
    #product name 
    try:
        product_name.append(result.find('h3',{'class':'name'})).get_text().strip()
    except:
            product_name.append('n/a')
            
    # product price 
    try:
        product_price.append(result.find('div',{'class':'prc'})).get_text().strip()
    except:
            product_price.append('n/a')
            
    # Product old price
    try:
        product_oldprice.append(result.find('div',{'class': 'old'})).get_text().strip()
    except:
            product_oldprice.append('n/a')
            
    # Product Discount
    try:
        product_discount.append(result.find('div',{'class': 'tag _dsct _sm'})).get_text().strip()
    except:
            product_discount.append('n/a')
        
    # Product rating
    try:
        product_rating.append(result.find('div',{'class':'rev'})).get_text().strip()
    except:
            product_rating.append('n/a')
            
    # Product Url
    try:
        product_url.append(result.find('a').get('href')).strip()
    except:
            product_url.append('n/a')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-27-040595d2308e> in <module>
#      10
#      11     #request
# ---> 12     me = requests.get(website)
#      13
#      14     # Soup
#
# ~\anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# ~\anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     653
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#     657         # Total elapsed time of the request (approximately)
#
# ~\anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     437         try:
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#     441                     url=url,
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     697
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#     701                 method,
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     380         # Trigger any extra validation we need to do.
#     381         try:
# --> 382             self._validate_conn(conn)
#     383         except (SocketTimeout, BaseSSLError) as e:
#     384             # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#    1008         # Force connect early to allow us to validate the connection.
#    1009         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1010             conn.connect()
#    1011
#    1012         if not conn.is_verified:
#
# ~\anaconda3\lib\site-packages\urllib3\connection.py in connect(self)
#     409             context.load_default_certs()
#     410
# --> 411         self.sock = ssl_wrap_socket(
#     412             sock=conn,
#     413             keyfile=self.key_file,
#
# ~\anaconda3\lib\site-packages\urllib3\util\ssl_.py in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     426
#     427     if send_sni:
# --> 428         ssl_sock = _ssl_wrap_socket_impl(
#     429             sock, context, tls_in_tls, server_hostname=server_hostname
#     430         )
#
# ~\anaconda3\lib\site-packages\urllib3\util\ssl_.py in _ssl_wrap_socket_impl(sock, ssl_context, tls_in_tls, server_hostname)
#     470
#     471     if server_hostname:
# --> 472         return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#     473     else:
#     474         return ssl_context.wrap_socket(sock)
#
# ~\anaconda3\lib\ssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     498         # SSLSocket class handles server_hostname encoding before it calls
#     499         # ctx._wrap_socket()
# --> 500         return self.sslsocket_class._create(
#     501             sock=sock,
#     502             server_side=server_side,
#
# ~\anaconda3\lib\ssl.py in _create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1038                         # non-blocking
#    1039                         raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1040                     self.do_handshake()
#    1041             except (OSError, ValueError):
#    1042                 self.close()
#
# ~\anaconda3\lib\ssl.py in do_handshake(self, block)
#    1307             if timeout == 0.0 and block:
#    1308                 self.settimeout(None)
# -> 1309             self._sslobj.do_handshake()
#    1310         finally:
#    1311             self.settimeout(timeout)
#
# KeyboardInterrupt:

# %%
me_overview = pd.DataFrame ({'Product name': product_name,
                                'Old price': product_oldprice,
                                'New price': product_price,
                                'Discount': product_discount,
                                'Rating': product_rating,
                                'Url':product_url})

# %%
print(me_overview)

# %% [markdown]
# # Running Through Again

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
website = 'https://www.jumia.com.ng/mobile-phone-accessory-kits/'

# %%
response = requests.get(website)

# %%
response.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(response.content, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en"><head><meta charset="utf-8"/><title>Phone Accessory Kits | Buy Phone Accessory Kits Online in Nigeria | Jumia NG</title><meta content="product" property="og:type"/><meta content="Jumia Nigeria" property="og:site_name"/><meta content="Phone Accessory Kits | Buy Phone Accessory Kits Online in Nigeria | Jumia NG" property="og:title"/><meta content="Amazing Deals during Black Friday. Shop for Phone Accessory Kits online on Jumia Nigeria. Discover a great selection of Phone Accessory Kits ✓ Best prices in Nigeria ✓ Enjoy cash on delivery - Order Now!" property="og:description"/><meta content="/mobile-phone-accessory-kits/" property="og:url"/><meta content="https://ng.jumia.is/cms/jumialogonew.png" property="og:image"/><meta content="en_NG" property="og:locale"/><meta content="Phone Accessory Kits | Buy Phone Accessory Kits Online in Nigeria | Jumia NG" name="title"/><meta content="index,follow" name="robots"/><meta content="Amazing Deals during Black Friday. Shop for Phone Accessory Kits online on Jumia Nigeria. Discover a great selection of Phone Accessory Kits ✓ Best prices in Nigeria ✓ Enjoy cash on delivery - Order Now!" name="description"/><link href="android-app://com.jumia.android/JUMIA/NG/c/mobile-phone-accessory-kits?utm_source=google&amp;utm_medium=organic&amp;adjust_tracker=j1hd8h&amp;adjust_campaign=GOOGLE_SEARCH&amp;adjust_adgroup=https%3A%2F%2Fwww.jumia.com.ng%2Fmobile-phone-accessory-kits%2F" rel="alternate"/><link href="https://www.jumia.com.ng/mobile-phone-accessory-kits/" rel="canonical"/><link href="https://www.jumia.com.ng/mobile-phone-accessory-kits/?page=2" rel="next"/><meta content="728795990650684" property="fb:app_id"/><meta content="291297097615087" property="fb:pages"/><meta content="4vr0StQ8YkyEzgDxkC_mgx0UMSH2xM3vkOaRpaMEjWM" name="google-site-verification"/><meta content="66DCE7076C4C56245BAB83C687510491" name="msvalidate.01"/><meta content="width=device-width, initial-scale=1.0" name="viewport"/><link href="https://www.jumia.com.ng/assets_he/css/main.1f1af2d1.css" rel="stylesheet"/><link href="https://www.jumia.com.ng/assets_he/favicon.dbe4090f.ico" rel="icon" type="image/ico"/><link href="//bam.nr-data.net" rel="preconnect dns-prefetch"/><link href="//js-agent.newrelic.com" rel="preconnect dns-prefetch"/><link href="//www.google-analytics.com" rel="preconnect dns-prefetch"/><link href="//www.googletagmanager.com" rel="preconnect dns-prefetch"/><link href="//www.facebook.com" rel="preconnect dns-prefetch"/><link href="//connect.facebook.net" rel="preconnect dns-prefetch"/><link href="//static.criteo.net" rel="preconnect dns-prefetch"/><link href="//sslwidget.criteo.com" rel="preconnect dns-prefetch"/><link href="//dis.eu.criteo.com" rel="preconnect dns-prefetch"/><link href="//creativecdn.com" rel="preconnect dns-prefetch"/><link href="https://ng.jumia.is" rel="dns-prefetch"/></head><body><script type="text/javascript">window.NREUM||(NREUM={});NREUM.info = {"agent":"","beacon":"bam-cell.nr-data.net","errorBeacon":"bam-cell.nr-data.net","licenseKey":"b76de0635f","applicationID":"202020352","applicationTime":15.643209,"transactionName":"NVxXYhMHChFYVUELDQwWdkMSEgsPFnVUFgMOVlIWHUY0LWpi","queueTime":0,"ttGuid":"cc7238d712b75407","agentToken":null}; (window.NREUM||(NREUM={})).init={ajax:{deny_list:["bam-cell.nr-data.net"]}};(window.NREUM||(NREUM={})).loader_config={licenseKey:"b76de0635f",applicationID:"202020352"};window.NREUM||(NREUM={}),__nr_require=function(t,e,n){function r(n){if(!e[n]){var i=e[n]={exports:{}};t[n][0].call(i.exports,function(e){var i=t[n][1][e];return r(i||e)},i,i.exports)}return e[n].exports}if("function"==typeof __nr_require)return __nr_require;for(var i=0;i<n.length;i++)r(n[i]);return r}({1:[function(t,e,n){function r(){}function i(t,e,n,r){return function(){return s.recordSupportability("API/"+e+"/called"),o(t+e,[u.now()].concat(c(arguments)),n?null:this,r),n?void 0:this}}var o=t("handle"),a=t(10),c=t(11),f=t("ee").get("tracer"),u=t("loader"),s=t(4),d=NRE ...

# %% [markdown]
# ## Results

# %%
results = soup.find_all('a', {'class':'core'})

# %%
len(results)
# Out:
# 48

# %%
results[0]
# Out:
# <a class="core" data-brand="Generic" data-category="Phones &amp; Tablets/Accessories/Accessory Kits" data-dimension23="287153" data-dimension26="" data-dimension27="" data-dimension28="0" data-dimension37="0" data-dimension43="TBOOST|TW22|TW_02" data-dimension44="0" data-id="GE779EA1SJ07KNAFAMZ" data-list="" data-name="Black Replacement Strap For Xiaomi Mi Band 5/6 Silicone Wristband" data-position="1" data-price="3.74" data-track-onclick="eecProduct" data-track-onview="eecProduct" href="/generic-black-replacement-strap-for-xiaomi-mi-band-56-silicone-wristband-106128380.html"><div class="img-c"><img alt="" class="img" data-lazy="" data-src="https://ng.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/08/3821601/1.jpg?7108" height="208" src="..." width="208"/><img alt="TW22" class="_ni camp" data-lazy="" data-src="https://ng.jumia.is/badges/tw22/1/138x18.png?8911" src="..."/></div><div class="info"><h3 class="name">Black Replacement Strap For Xiaomi Mi Band 5/6 Silicone Wristband</h3><div class="prc">₦ 1,710</div><div class="s-prc-w"><div class="old">₦ 2,000</div><div class="tag _dsct _sm">15%</div></div></div></a>

# %% [markdown]
# ## Target  Neccessary Data

# %%
# Product Name

results[0].find('h3',{'class':'name'}).get_text()
# Out:
# 'Black Replacement Strap For Xiaomi Mi Band 5/6 Silicone Wristband'

# %%
# New Product Price 

results[0].find('div', {'class':'prc'}).get_text()
# Out:
# '₦ 1,710'

# %%
# Old Product Price

results[0].find('div', {'class':'old'}).get_text()
# Out:
# '₦ 2,000'

# %%
# DIscount Given 

results[0].find('div', {'class':'tag _dsct _sm'}).get_text()
# Out:
# '15%'

# %%
# Rating Stars

results[4].find('div', {'class':'stars _s'}).get_text()
# Out:
# '3 out of 5'

# %%
# Ratings Count

results[2].find('div', {'class':'rev'})
#.get_text()
# Out:
# <div class="rev"><div class="stars _s">4.7 out of 5<div class="in" style="width:94%"></div></div>(6)</div>

# %%
# Relative Url

results[2].find('a').get('href')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-50-53b4dd6023fe> in <module>
#       1 # Relative Url
#       2
# ----> 3 results[2].find('a').get('href')
#
# AttributeError: 'NoneType' object has no attribute 'get'
